# %%
from riichienv import parse_hand
from riichienv import convert as cvt
from riichienv.visualizer import Replay

events = [
    {'id': 0, 'type': 'start_game'},
    {'bakaze': 'E',
     'dora_marker': '5s',
     'honba': 0,
     'kyoku': 1,
     'kyotaku': 0,
     'oya': 0,
     'scores': [25000, 25000, 25000, 25000],
     'tehais': [
         cvt.tid_to_mjai_list(parse_hand("2224557m4068p89s")[0]),
         cvt.tid_to_mjai_list(parse_hand("177m3349p2679s67z")[0]),
         cvt.tid_to_mjai_list(parse_hand("55689p1338s2577z")[0]),
         cvt.tid_to_mjai_list(parse_hand("18m4p23406789s67z")[0]),
     ],
    'type': 'start_kyoku'},
    {'actor': 0, 'pai': 'F', 'type': 'tsumo'},
    {'actor': 0, 'pai': '8s', 'tsumogiri': False, 'type': 'dahai'},
    {'actor': 1, 'consumed': ['6s', '7s'], 'pai': '8s', 'target': 0, 'type': 'chi'},
]

Replay.from_list(events, step=4, perspective=0, freeze=True)
# Out:
#         <div id="riichienv-viewer-020fedca-9e7f-4329-a3d6-cbd2e2748651" style="width: 100%; min-height: 600px; border: 1px solid #ddd; box-sizing: border-box;">
#              <div style="padding: 20px; text-align: center; font-family: sans-serif; color: #666;">
#                 Loading RiichiEnv Replay...
#              </div>
#         </div>
#         <script>
#         (function() {
#             const expectedHash = "2b96d70ef27a8ca570e1b00e6a666ccf";
#
#             const runViewer = (jsCode) => {
#                 try {
#                     if (jsCode) {
#                         const script = document.createElement('script');
#                         script.text = jsCode;
#                         document.head.appendChild(script);
#                         // Store the hash after loading new code
#                         window.RiichiEnvViewerHash = expectedHash;
#                     }
#
#                     const logData = [{"id": 0, "type": "start_game", "meta": {}}, {"bakaze": "E", "dora_marker": "5s", "honba": 0, "kyoku": 1, "kyotaku": 0, "oya": 0, "scores": [25000, 25000, 25000, 25000], "tehais": [["2m", "2m", "2m", "4m", "5m", "5m", "7m", "4p", "5pr", "6p", "8p", "8s", "9s"], ["1m", "7m", "7m", "3p", "3p", "4p", "9p", "2s", "6s", "7s", "9s", "F", "C"], ["5p", "5p", "6p", "8p", "9p", "1s", "3s", "3s", "8s", "S", "P", "C", "C"], ["1m", "8m", "4p", "2s", "3s", "4s", "5sr", "6s", "7s", "8s", "9s", "F", "C"]], "type": "start_kyoku", "meta": {}}, {"actor": 0, "pai": "F", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "8s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "consumed": ["6s", "7s"], "pai": "8s", "target": 0, "type": "chi", "meta": {}}];
#                     const initialStep = 4;
#                     const perspective = 0;
#                     const freeze = true;
#                     if (window.RiichiEnv3DViewer) {
#                         new window.RiichiEnv3DViewer("riichienv-viewer-020fedca-9e7f-4329-a3d6-cbd2e2748651", logData, initialStep, perspective, freeze);
#                     } else {
#                         throw new Error("RiichiEnv3DViewer global not found after injection");
#                     }
#                 } catch (e) {
#                     console.error("RiichiEnv Viewer Error:", e);
#                     document.getElementById("riichienv-viewer-020fedca-9e7f-4329-a3d6-cbd2e2748651").innerHTML = "Error: " + e.message;
#                 }
#             };
#
#             // Check if global exists AND matches expected hash
#             if (window.RiichiEnv3DViewer && window.RiichiEnvViewerHash === expectedHash) {
#                 runViewer("");
#             } else {
#                 // Decompress and load New Code
#                 const b64Data = "...";
#                 const compressed = Uint8Array.from(atob(b64Data), c => c.charCodeAt(0));
#
#                 if (window.DecompressionStream) {
#                     const ds = new DecompressionStream('gzip');
#                     const decompressedStream = new Response(compressed).body.pipeThrough(ds);
#                     new Response(decompressedStream).text().then(runViewer).catch(e => {
#                         document.getElementById("riichienv-viewer-020fedca-9e7f-4329-a3d6-cbd2e2748651").innerHTML = "Error decompressing: " + e.message;
#                     });
#                 } else {
#                     const err = "Error: Browser too old (DecompressionStream missing).";
#                     document.getElementById("riichienv-viewer-020fedca-9e7f-4329-a3d6-cbd2e2748651").innerHTML = err;
#                 }
#             }
#         })();
#         </script>
